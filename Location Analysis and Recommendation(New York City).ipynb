# %% [markdown]
# <h1>Battle of Neighborhoods </h1>

# %% [markdown]
# <h2>Location Analysis and Recommendation </h2>

# %% [markdown]
# <h4>Problem Statement:</h4>
# <P>A person wants to find a place for his stay in New York City. The person loves Asian food and hence wants to find a location where it is available. Using Foresquare API, the areas of the city are analyzed and explored to find an area with maximum number of Asian Restaurants. Furthermore, the avaibility of Market Places, Health Care Stores, Shopping Malls ,Salons etc are also to taken into consideration while finding the best location. Finally a list of all venues in the selected neighborhood is given and plotted on the map.
#     <P> A list of other requirements to be considered for the above problem are:
#
# <h4>Essential Requirements:</h4>
# <ol>
#     <li>Bank</li>
#     <li>Bakery</li>
#     <li>Pharmacy</li>
#     <li>Market/Store/Shop</li>
#     <li>Salon</li>
#     <li>Health and Beauty Service</li>
#     <li>Gym</li>
#      <li>Park</li>
#     <li>Spa</li>
# </ol>
#
# <h4>Non-Essential Requirements:</h4>
# <ol>
#     <li>Tea Shop</li>
#     <li>Tea Room</li>
# </ol>

# %% [markdown]
# <h4>Objectives:</h4>
# <ol>
#     <li>To find out the Asian Restaurants in New York City </li>
#     <li>To find the Borough with maximum Asian Restaurants</li>
#     <li>To explore the neighborhoods for highest number of Asian Restaurants for the above result of the Borough </li>
#     <li>To explore the above selected neighborhoods for the other requirements as per the list in the above problem statement.</li>
#     <li>To find the neighborhood which fulfills most of the essential requirements</li>
#     <li>To explore the neighborhood further and give a list of all venues in the area</li>
#     <li>Cluster all the venues and the necessary venues on a map</li>
# </ol>
# <P>Based on the above findings,the most preferred area is suggested whose all venues are plotted as cluster on the map </P>
# <P>Another neighborhood is suggested based on the next best suited area</P>

# %%
#importing libraries
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json
from pandas.io.json import json_normalize



from geopy.geocoders import Nominatim



import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans


import folium

import requests

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# <h3> Loading and Cleaning Data</h3>

# %% [markdown]
# <h4>New York Data</h4>

# %% [markdown]
# The dataset is downloaded via the link: https://geo.nyu.edu/catalog/nyu_2451_34572 which is renamed as newyorkdata.csv for convenience.

# %%
df1=pd.read_csv("newyorkdata.csv")
df1.head(10)
# Out:
#      Borough    Neighborhood   Latitude  Longitude
# 0      Bronx       Wakefield  40.894705 -73.847201
# 1      Bronx      Co-op City  40.874294 -73.829939
# 2      Bronx     Eastchester  40.887556 -73.827806
# 3      Bronx       Fieldston  40.895437 -73.905643
# 4      Bronx       Riverdale  40.890834 -73.912585
# 5      Bronx     Kingsbridge  40.881687 -73.902818
# 6  Manhattan     Marble Hill  40.876551 -73.910660
# 7      Bronx        Woodlawn  40.898273 -73.867315
# 8      Bronx         Norwood  40.877224 -73.879391
# 9      Bronx  Williamsbridge  40.881039 -73.857446

# %% [markdown]
# Finding the count of neighborhoods for each Borough of the given dataframe

# %%
 df1.groupby("Borough").count()
# Out:
#                Neighborhood  Latitude  Longitude
# Borough
# Bronx                    52        52         52
# Brooklyn                 70        70         70
# Manhattan                40        40         40
# Queens                   81        81         81
# Staten Island            63        63         63

# %%
df1.shape
# Out:
# (306, 4)

# %% [markdown]
# <h4>Finding Latitudes and Longitudes of New York City</h4>

# %%
address = 'New York,NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York are 40.7127281, -74.0060152.

# %% [markdown]
# <h4>Visualizing the neighborhoods data for New York City as clusters</h4>

# %%
#creating map of New York using Latitude and Longitude values for Visualization
map_ny = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df1['Latitude'], df1['Longitude'], df1['Borough'], df1['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ny)  
    
map_ny
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h4>Neighborhood count graph of each Borough</h4>
#
# A graph is plotted with the Boroughs and the number of neighborhoods in each Borough to visualize the distribution of neighborhoods over each Brough.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Neighborhood for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Neighborhood', fontsize=15)
#giving a bar plot
df1.groupby('Borough')['Neighborhood'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# <h3>Foresquare API</h3>

# %% [markdown]
# <h4>Getting the credentials</h4>

# %%
CLIENT_ID = '3G1FFILZXJ40SISIZQ32YIBEG5S0WTBLOFCOGKO3L2LFITXJ'
CLIENT_SECRET = 'EG1T4EMV1U3PNHEIGRPSBQZBSZPPTF2ETI45MX04O0FWU2MY' 
VERSION = '20180605'

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3G1FFILZXJ40SISIZQ32YIBEG5S0WTBLOFCOGKO3L2LFITXJ
# CLIENT_SECRET:EG1T4EMV1U3PNHEIGRPSBQZBSZPPTF2ETI45MX04O0FWU2MY

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=1000
    LIMIT=100
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name']
asian_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in df1.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    asian_restaurants=venues[venues['Category']=='Asian Restaurant']   
    print('(',count,'/',len(df1),')','Asian Resturants in '+Neighborhood+', '+Borough+':'+str(len(asian_restaurants)))
    for restaurant_detail in asian_restaurants.values.tolist():
        id, name , category=restaurant_detail
        asian_rest_ny = asian_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Asian Resturants in Wakefield, Bronx:1
# ( 2 / 306 ) Asian Resturants in Co-op City, Bronx:0
# ( 3 / 306 ) Asian Resturants in Eastchester, Bronx:2
# ( 4 / 306 ) Asian Resturants in Fieldston, Bronx:0
# ( 5 / 306 ) Asian Resturants in Riverdale, Bronx:0
# ( 6 / 306 ) Asian Resturants in Kingsbridge, Bronx:0
# ( 7 / 306 ) Asian Resturants in Marble Hill, Manhattan:0
# ( 8 / 306 ) Asian Resturants in Woodlawn, Bronx:0
# ( 9 / 306 ) Asian Resturants in Norwood, Bronx:0
# ( 10 / 306 ) Asian Resturants in Williamsbridge, Bronx:0
# ( 11 / 306 ) Asian Resturants in Baychester, Bronx:0
# ( 12 / 306 ) Asian Resturants in Pelham Parkway, Bronx:0
# ( 13 / 306 ) Asian Resturants in City Island, Bronx:0
# ( 14 / 306 ) Asian Resturants in Bedford Park, Bronx:0
# ( 15 / 306 ) Asian Resturants in University Heights, Bronx:0
# ( 16 / 306 ) Asian Resturants in Morris Heights, Bronx:1
# ( 17 / 306 ) Asian Resturants in Fordham, Bronx:0
# ( 18 / 306 ) Asian Resturants in East Tremont, Bronx:0
# ( 19 / 306 ) Asian Resturants in West Farms, Bronx:0
# ( 20 / 306 ) Asian Resturants in High  Bridge, Bronx:0
# ( 21 / 306 ) Asian Resturants in Melrose, Bronx:0
# ( 22 / 306 ) Asian Resturants in Mott Haven, Bronx:1
# ( 23 / 306 ) Asian Resturants in Port Morris, Bronx:0
# ( 24 / 306 ) Asian Resturants in Longwood, Bronx:0
# ( 25 / 306 ) Asian Resturants in Hunts Point, Bronx:0
# ( 26 / 306 ) Asian Resturants in Morrisania, Bronx:0
# ( 27 / 306 ) Asian Resturants in Soundview, Bronx:0
# ( 28 / 306 ) Asian Resturants in Clason Point, Bronx:0
# ( 29 / 306 ) Asian Resturants in Throgs Neck, Bronx:1
# ( 30 / 306 ) Asian Resturants in Country Club, Bronx:1
# ( 31 / 306 ) Asian Resturants in Parkchester, Bronx:1
# ( 32 / 306 ) Asian Resturants in Westchester Square, Bronx:1
# ( 33 / 306 ) Asian Resturants in Van Nest, Bronx:0
# ( 34 / 306 ) Asian Resturants in Morris Park, Bronx:1
# ( 35 / 306 ) Asian Resturants in Belmont, Bronx:0
# ( 36 / 306 ) Asian Resturants in Spuyten Duyvil, Bronx:0
# ( 37 / 306 ) Asian Resturants in North Riverdale, Bronx:0
# ( 38 / 306 ) Asian Resturants in Pelham Bay, Bronx:1
# ( 39 / 306 ) Asian Resturants in Schuylerville, Bronx:0
# ( 40 / 306 ) Asian Resturants in Edgewater Park, Bronx:1
# ( 41 / 306 ) Asian Resturants in Castle Hill, Bronx:0
# ( 42 / 306 ) Asian Resturants in Olinville, Bronx:0
# ( 43 / 306 ) Asian Resturants in Pelham Gardens, Bronx:0
# ( 44 / 306 ) Asian Resturants in Concourse, Bronx:0
# ( 45 / 306 ) Asian Resturants in Unionport, Bronx:1
# ( 46 / 306 ) Asian Resturants in Edenwald, Bronx:0
# ( 47 / 306 ) Asian Resturants in Bay Ridge, Brooklyn:1
# ( 48 / 306 ) Asian Resturants in Bensonhurst, Brooklyn:1
# ( 49 / 306 ) Asian Resturants in Sunset Park, Brooklyn:3
# ( 50 / 306 ) Asian Resturants in Greenpoint, Brooklyn:0
# ( 51 / 306 ) Asian Resturants in Gravesend, Brooklyn:0
# ( 52 / 306 ) Asian Resturants in Brighton Beach, Brooklyn:1
# ( 53 / 306 ) Asian Resturants in Sheepshead Bay, Brooklyn:0
# ( 54 / 306 ) Asian Resturants in Manhattan Terrace, Brooklyn:0
# ( 55 / 306 ) Asian Resturants in Flatbush, Brooklyn:0
# ( 56 / 306 ) Asian Resturants in Crown Heights, Brooklyn:0
# ( 57 / 306 ) Asian Resturants in East Flatbush, Brooklyn:0
# ( 58 / 306 ) Asian Resturants in Kensington, Brooklyn:0
# ( 59 / 306 ) Asian Resturants in Windsor Terrace, Brooklyn:0
# ( 60 / 306 ) Asian Resturants in Prospect Heights, Brooklyn:0
# ( 61 / 306 ) Asian Resturants in Brownsville, Brooklyn:0
# ( 62 / 306 ) Asian Resturants in Williamsburg, Brooklyn:0
# ( 63 / 306 ) Asian Resturants in Bushwick, Brooklyn:1
# ( 64 / 306 ) Asian Resturants in Bedford Stuyvesant, Brooklyn:0
# ( 65 / 306 ) Asian Resturants in Brooklyn Heights, Brooklyn:0
# ( 66 / 306 ) Asian Resturants in Cobble Hill, Brooklyn:0
# ( 67 / 306 ) Asian Resturants in Carroll Gardens, Brooklyn:0
# ( 68 / 306 ) Asian Resturants in Red Hook, Brooklyn:0
# ( 69 / 306 ) Asian Resturants in Gowanus, Brooklyn:0
# ( 70 / 306 ) Asian Resturants in Fort Greene, Brooklyn:0
# ( 71 / 306 ) Asian Resturants in Park Slope, Brooklyn:0
# ( 72 / 306 ) Asian Resturants in Cypress Hills, Brooklyn:0
# ( 73 / 306 ) Asian Resturants in East New York, Brooklyn:0
# ( 74 / 306 ) Asian Resturants in Starrett City, Brooklyn:0
# ( 75 / 306 ) Asian Resturants in Canarsie, Brooklyn:0
# ( 76 / 306 ) Asian Resturants in Flatlands, Brooklyn:0
# ( 77 / 306 ) Asian Resturants in Mill Island, Brooklyn:0
# ( 78 / 306 ) Asian Resturants in Manhattan Beach, Brooklyn:1
# ( 79 / 306 ) Asian Resturants in Coney Island, Brooklyn:1
# ( 80 / 306 ) Asian Resturants in Bath Beach, Brooklyn:2
# ( 81 / 306 ) Asian Resturants in Borough Park, Brooklyn:0
# ( 82 / 306 ) Asian Resturants in Dyker Heights, Brooklyn:1
# ( 83 / 306 ) Asian Resturants in Gerritsen Beach, Brooklyn:0
# ( 84 / 306 ) Asian Resturants in Marine Park, Brooklyn:0
# ( 85 / 306 ) Asian Resturants in Clinton Hill, Brooklyn:1
# ( 86 / 306 ) Asian Resturants in Sea Gate, Brooklyn:0
# ( 87 / 306 ) Asian Resturants in Downtown, Brooklyn:0
# ( 88 / 306 ) Asian Resturants in Boerum Hill, Brooklyn:0
# ( 89 / 306 ) Asian Resturants in Prospect Lefferts Gardens, Brooklyn:0
# ( 90 / 306 ) Asian Resturants in Ocean Hill, Brooklyn:0
# ( 91 / 306 ) Asian Resturants in City Line, Brooklyn:1
# ( 92 / 306 ) Asian Resturants in Bergen Beach, Brooklyn:0
# ( 93 / 306 ) Asian Resturants in Midwood, Brooklyn:0
# ( 94 / 306 ) Asian Resturants in Prospect Park South, Brooklyn:1
# ( 95 / 306 ) Asian Resturants in Georgetown, Brooklyn:0
# ( 96 / 306 ) Asian Resturants in East Williamsburg, Brooklyn:0
# ( 97 / 306 ) Asian Resturants in North Side, Brooklyn:1
# ( 98 / 306 ) Asian Resturants in South Side, Brooklyn:1
# ( 99 / 306 ) Asian Resturants in Ocean Parkway, Brooklyn:0
# ( 100 / 306 ) Asian Resturants in Fort Hamilton, Brooklyn:1
# ( 101 / 306 ) Asian Resturants in Chinatown, Manhattan:2
# ( 102 / 306 ) Asian Resturants in Washington Heights, Manhattan:1
# ( 103 / 306 ) Asian Resturants in Inwood, Manhattan:0
# ( 104 / 306 ) Asian Resturants in Hamilton Heights, Manhattan:0
# ( 105 / 306 ) Asian Resturants in Manhattanville, Manhattan:0
# ( 106 / 306 ) Asian Resturants in Central Harlem, Manhattan:0
# ( 107 / 306 ) Asian Resturants in East Harlem, Manhattan:0
# ( 108 / 306 ) Asian Resturants in Upper East Side, Manhattan:0
# ( 109 / 306 ) Asian Resturants in Yorkville, Manhattan:1
# ( 110 / 306 ) Asian Resturants in Lenox Hill, Manhattan:0
# ( 111 / 306 ) Asian Resturants in Roosevelt Island, Manhattan:0
# ( 112 / 306 ) Asian Resturants in Upper West Side, Manhattan:0
# ( 113 / 306 ) Asian Resturants in Lincoln Square, Manhattan:0
# ( 114 / 306 ) Asian Resturants in Clinton, Manhattan:0
# ( 115 / 306 ) Asian Resturants in Midtown, Manhattan:0
# ( 116 / 306 ) Asian Resturants in Murray Hill, Manhattan:0
# ( 117 / 306 ) Asian Resturants in Chelsea, Manhattan:0
# ( 118 / 306 ) Asian Resturants in Greenwich Village, Manhattan:0
# ( 119 / 306 ) Asian Resturants in East Village, Manhattan:1
# ( 120 / 306 ) Asian Resturants in Lower East Side, Manhattan:2
# ( 121 / 306 ) Asian Resturants in Tribeca, Manhattan:1
# ( 122 / 306 ) Asian Resturants in Little Italy, Manhattan:1
# ( 123 / 306 ) Asian Resturants in Soho, Manhattan:0
# ( 124 / 306 ) Asian Resturants in West Village, Manhattan:0
# ( 125 / 306 ) Asian Resturants in Manhattan Valley, Manhattan:0
# ( 126 / 306 ) Asian Resturants in Morningside Heights, Manhattan:0
# ( 127 / 306 ) Asian Resturants in Gramercy, Manhattan:1
# ( 128 / 306 ) Asian Resturants in Battery Park City, Manhattan:0
# ( 129 / 306 ) Asian Resturants in Financial District, Manhattan:0
# ( 130 / 306 ) Asian Resturants in Astoria, Queens:1
# ( 131 / 306 ) Asian Resturants in Woodside, Queens:0
# ( 132 / 306 ) Asian Resturants in Jackson Heights, Queens:1
# ( 133 / 306 ) Asian Resturants in Elmhurst, Queens:2
# ( 134 / 306 ) Asian Resturants in Howard Beach, Queens:0
# ( 135 / 306 ) Asian Resturants in Corona, Queens:0
# ( 136 / 306 ) Asian Resturants in Forest Hills, Queens:3
# ( 137 / 306 ) Asian Resturants in Kew Gardens, Queens:0
# ( 138 / 306 ) Asian Resturants in Richmond Hill, Queens:0
# ( 139 / 306 ) Asian Resturants in Flushing, Queens:3
# ( 140 / 306 ) Asian Resturants in Long Island City, Queens:0
# ( 141 / 306 ) Asian Resturants in Sunnyside, Queens:1
# ( 142 / 306 ) Asian Resturants in East Elmhurst, Queens:0
# ( 143 / 306 ) Asian Resturants in Maspeth, Queens:1
# ( 144 / 306 ) Asian Resturants in Ridgewood, Queens:0
# ( 145 / 306 ) Asian Resturants in Glendale, Queens:0
# ( 146 / 306 ) Asian Resturants in Rego Park, Queens:2
# ( 147 / 306 ) Asian Resturants in Woodhaven, Queens:2
# ( 148 / 306 ) Asian Resturants in Ozone Park, Queens:0
# ( 149 / 306 ) Asian Resturants in South Ozone Park, Queens:0
# ( 150 / 306 ) Asian Resturants in College Point, Queens:2
# ( 151 / 306 ) Asian Resturants in Whitestone, Queens:1
# ( 152 / 306 ) Asian Resturants in Bayside, Queens:3
# ( 153 / 306 ) Asian Resturants in Auburndale, Queens:0
# ( 154 / 306 ) Asian Resturants in Little Neck, Queens:1
# ( 155 / 306 ) Asian Resturants in Douglaston, Queens:0
# ( 156 / 306 ) Asian Resturants in Glen Oaks, Queens:1
# ( 157 / 306 ) Asian Resturants in Bellerose, Queens:0
# ( 158 / 306 ) Asian Resturants in Kew Gardens Hills, Queens:2
# ( 159 / 306 ) Asian Resturants in Fresh Meadows, Queens:2
# ( 160 / 306 ) Asian Resturants in Briarwood, Queens:1
# ( 161 / 306 ) Asian Resturants in Jamaica Center, Queens:0
# ( 162 / 306 ) Asian Resturants in Oakland Gardens, Queens:1
# ( 163 / 306 ) Asian Resturants in Queens Village, Queens:0
# ( 164 / 306 ) Asian Resturants in Hollis, Queens:0
# ( 165 / 306 ) Asian Resturants in South Jamaica, Queens:0
# ( 166 / 306 ) Asian Resturants in St. Albans, Queens:0
# ( 167 / 306 ) Asian Resturants in Rochdale, Queens:0
# ( 168 / 306 ) Asian Resturants in Springfield Gardens, Queens:0
# ( 169 / 306 ) Asian Resturants in Cambria Heights, Queens:0
# ( 170 / 306 ) Asian Resturants in Rosedale, Queens:0
# ( 171 / 306 ) Asian Resturants in Far Rockaway, Queens:0
# ( 172 / 306 ) Asian Resturants in Broad Channel, Queens:0
# ( 173 / 306 ) Asian Resturants in Breezy Point, Queens:0
# ( 174 / 306 ) Asian Resturants in Steinway, Queens:1
# ( 175 / 306 ) Asian Resturants in Beechhurst, Queens:0
# ( 176 / 306 ) Asian Resturants in Bay Terrace, Queens:0
# ( 177 / 306 ) Asian Resturants in Edgemere, Queens:1
# ( 178 / 306 ) Asian Resturants in Arverne, Queens:0
# ( 179 / 306 ) Asian Resturants in Rockaway Beach, Queens:0
# ( 180 / 306 ) Asian Resturants in Neponsit, Queens:0
# ( 181 / 306 ) Asian Resturants in Murray Hill, Queens:2
# ( 182 / 306 ) Asian Resturants in Floral Park, Queens:1
# ( 183 / 306 ) Asian Resturants in Holliswood, Queens:1
# ( 184 / 306 ) Asian Resturants in Jamaica Estates, Queens:0
# ( 185 / 306 ) Asian Resturants in Queensboro Hill, Queens:2
# ( 186 / 306 ) Asian Resturants in Hillcrest, Queens:1
# ( 187 / 306 ) Asian Resturants in Ravenswood, Queens:0
# ( 188 / 306 ) Asian Resturants in Lindenwood, Queens:0
# ( 189 / 306 ) Asian Resturants in Laurelton, Queens:0
# ( 190 / 306 ) Asian Resturants in Lefrak City, Queens:0
# ( 191 / 306 ) Asian Resturants in Belle Harbor, Queens:0
# ( 192 / 306 ) Asian Resturants in Rockaway Park, Queens:0
# ( 193 / 306 ) Asian Resturants in Somerville, Queens:0
# ( 194 / 306 ) Asian Resturants in Brookville, Queens:0
# ( 195 / 306 ) Asian Resturants in Bellaire, Queens:0
# ( 196 / 306 ) Asian Resturants in North Corona, Queens:0
# ( 197 / 306 ) Asian Resturants in Forest Hills Gardens, Queens:1
# ( 198 / 306 ) Asian Resturants in St. George, Staten Island:0
# ( 199 / 306 ) Asian Resturants in New Brighton, Staten Island:0
# ( 200 / 306 ) Asian Resturants in Stapleton, Staten Island:1
# ( 201 / 306 ) Asian Resturants in Rosebank, Staten Island:0
# ( 202 / 306 ) Asian Resturants in West Brighton, Staten Island:0
# ( 203 / 306 ) Asian Resturants in Grymes Hill, Staten Island:0
# ( 204 / 306 ) Asian Resturants in Todt Hill, Staten Island:0
# ( 205 / 306 ) Asian Resturants in South Beach, Staten Island:0
# ( 206 / 306 ) Asian Resturants in Port Richmond, Staten Island:0
# ( 207 / 306 ) Asian Resturants in Mariner's Harbor, Staten Island:0
# ( 208 / 306 ) Asian Resturants in Port Ivory, Staten Island:0
# ( 209 / 306 ) Asian Resturants in Castleton Corners, Staten Island:0
# ( 210 / 306 ) Asian Resturants in New Springville, Staten Island:0
# ( 211 / 306 ) Asian Resturants in Travis, Staten Island:0
# ( 212 / 306 ) Asian Resturants in New Dorp, Staten Island:2
# ( 213 / 306 ) Asian Resturants in Oakwood, Staten Island:1
# ( 214 / 306 ) Asian Resturants in Great Kills, Staten Island:0
# ( 215 / 306 ) Asian Resturants in Eltingville, Staten Island:0
# ( 216 / 306 ) Asian Resturants in Annadale, Staten Island:0
# ( 217 / 306 ) Asian Resturants in Woodrow, Staten Island:0
# ( 218 / 306 ) Asian Resturants in Tottenville, Staten Island:1
# ( 219 / 306 ) Asian Resturants in Tompkinsville, Staten Island:0
# ( 220 / 306 ) Asian Resturants in Silver Lake, Staten Island:0
# ( 221 / 306 ) Asian Resturants in Sunnyside, Staten Island:0
# ( 222 / 306 ) Asian Resturants in Ditmas Park, Brooklyn:1
# ( 223 / 306 ) Asian Resturants in Wingate, Brooklyn:0
# ( 224 / 306 ) Asian Resturants in Rugby, Brooklyn:0
# ( 225 / 306 ) Asian Resturants in Park Hill, Staten Island:0
# ( 226 / 306 ) Asian Resturants in Westerleigh, Staten Island:2
# ( 227 / 306 ) Asian Resturants in Graniteville, Staten Island:1
# ( 228 / 306 ) Asian Resturants in Arlington, Staten Island:0
# ( 229 / 306 ) Asian Resturants in Arrochar, Staten Island:0
# ( 230 / 306 ) Asian Resturants in Grasmere, Staten Island:0
# ( 231 / 306 ) Asian Resturants in Old Town, Staten Island:0
# ( 232 / 306 ) Asian Resturants in Dongan Hills, Staten Island:1
# ( 233 / 306 ) Asian Resturants in Midland Beach, Staten Island:2
# ( 234 / 306 ) Asian Resturants in Grant City, Staten Island:3
# ( 235 / 306 ) Asian Resturants in New Dorp Beach, Staten Island:1
# ( 236 / 306 ) Asian Resturants in Bay Terrace, Staten Island:0
# ( 237 / 306 ) Asian Resturants in Huguenot, Staten Island:0
# ( 238 / 306 ) Asian Resturants in Pleasant Plains, Staten Island:0
# ( 239 / 306 ) Asian Resturants in Butler Manor, Staten Island:0
# ( 240 / 306 ) Asian Resturants in Charleston, Staten Island:0
# ( 241 / 306 ) Asian Resturants in Rossville, Staten Island:0
# ( 242 / 306 ) Asian Resturants in Arden Heights, Staten Island:0
# ( 243 / 306 ) Asian Resturants in Greenridge, Staten Island:0
# ( 244 / 306 ) Asian Resturants in Heartland Village, Staten Island:0
# ( 245 / 306 ) Asian Resturants in Chelsea, Staten Island:0
# ( 246 / 306 ) Asian Resturants in Bloomfield, Staten Island:0
# ( 247 / 306 ) Asian Resturants in Bulls Head, Staten Island:0
# ( 248 / 306 ) Asian Resturants in Carnegie Hill, Manhattan:0
# ( 249 / 306 ) Asian Resturants in Noho, Manhattan:2
# ( 250 / 306 ) Asian Resturants in Civic Center, Manhattan:1
# ( 251 / 306 ) Asian Resturants in Midtown South, Manhattan:0
# ( 252 / 306 ) Asian Resturants in Richmond Town, Staten Island:0
# ( 253 / 306 ) Asian Resturants in Shore Acres, Staten Island:0
# ( 254 / 306 ) Asian Resturants in Clifton, Staten Island:0
# ( 255 / 306 ) Asian Resturants in Concord, Staten Island:0
# ( 256 / 306 ) Asian Resturants in Emerson Hill, Staten Island:0
# ( 257 / 306 ) Asian Resturants in Randall Manor, Staten Island:0
# ( 258 / 306 ) Asian Resturants in Howland Hook, Staten Island:0
# ( 259 / 306 ) Asian Resturants in Elm Park, Staten Island:2
# ( 260 / 306 ) Asian Resturants in Remsen Village, Brooklyn:0
# ( 261 / 306 ) Asian Resturants in New Lots, Brooklyn:1
# ( 262 / 306 ) Asian Resturants in Paerdegat Basin, Brooklyn:1
# ( 263 / 306 ) Asian Resturants in Mill Basin, Brooklyn:0
# ( 264 / 306 ) Asian Resturants in Jamaica Hills, Queens:0
# ( 265 / 306 ) Asian Resturants in Utopia, Queens:2
# ( 266 / 306 ) Asian Resturants in Pomonok, Queens:0
# ( 267 / 306 ) Asian Resturants in Astoria Heights, Queens:0
# ( 268 / 306 ) Asian Resturants in Claremont Village, Bronx:0
# ( 269 / 306 ) Asian Resturants in Concourse Village, Bronx:0
# ( 270 / 306 ) Asian Resturants in Mount Eden, Bronx:0
# ( 271 / 306 ) Asian Resturants in Mount Hope, Bronx:0
# ( 272 / 306 ) Asian Resturants in Sutton Place, Manhattan:0
# ( 273 / 306 ) Asian Resturants in Hunters Point, Queens:1
# ( 274 / 306 ) Asian Resturants in Turtle Bay, Manhattan:1
# ( 275 / 306 ) Asian Resturants in Tudor City, Manhattan:1
# ( 276 / 306 ) Asian Resturants in Stuyvesant Town, Manhattan:0
# ( 277 / 306 ) Asian Resturants in Flatiron, Manhattan:0
# ( 278 / 306 ) Asian Resturants in Sunnyside Gardens, Queens:1
# ( 279 / 306 ) Asian Resturants in Blissville, Queens:0
# ( 280 / 306 ) Asian Resturants in Fulton Ferry, Brooklyn:0
# ( 281 / 306 ) Asian Resturants in Vinegar Hill, Brooklyn:1
# ( 282 / 306 ) Asian Resturants in Weeksville, Brooklyn:0
# ( 283 / 306 ) Asian Resturants in Broadway Junction, Brooklyn:0
# ( 284 / 306 ) Asian Resturants in Dumbo, Brooklyn:0
# ( 285 / 306 ) Asian Resturants in Manor Heights, Staten Island:0
# ( 286 / 306 ) Asian Resturants in Willowbrook, Staten Island:0
# ( 287 / 306 ) Asian Resturants in Sandy Ground, Staten Island:0
# ( 288 / 306 ) Asian Resturants in Egbertville, Staten Island:0
# ( 289 / 306 ) Asian Resturants in Roxbury, Queens:0
# ( 290 / 306 ) Asian Resturants in Homecrest, Brooklyn:1
# ( 291 / 306 ) Asian Resturants in Middle Village, Queens:0
# ( 292 / 306 ) Asian Resturants in Prince's Bay, Staten Island:0
# ( 293 / 306 ) Asian Resturants in Lighthouse Hill, Staten Island:0
# ( 294 / 306 ) Asian Resturants in Richmond Valley, Staten Island:1
# ( 295 / 306 ) Asian Resturants in Malba, Queens:0
# ( 296 / 306 ) Asian Resturants in Highland Park, Brooklyn:0
# ( 297 / 306 ) Asian Resturants in Madison, Brooklyn:0
# ( 298 / 306 ) Asian Resturants in Bronxdale, Bronx:0
# ( 299 / 306 ) Asian Resturants in Allerton, Bronx:0
# ( 300 / 306 ) Asian Resturants in Kingsbridge Heights, Bronx:0
# ( 301 / 306 ) Asian Resturants in Erasmus, Brooklyn:0
# ( 302 / 306 ) Asian Resturants in Hudson Yards, Manhattan:0
# ( 303 / 306 ) Asian Resturants in Hammels, Queens:0
# ( 304 / 306 ) Asian Resturants in Bayswater, Queens:0
# ( 305 / 306 ) Asian Resturants in Queensbridge, Queens:0
# ( 306 / 306 ) Asian Resturants in Fox Hills, Staten Island:0

# %%
asian_rest_ny.head()
# Out:
#   Borough    Neighborhood                        ID  \
# 0   Bronx       Wakefield  4dbf038d432d1849fa379c49
# 1   Bronx     Eastchester  50f9fef3e4b0c2329117b8a8
# 2   Bronx     Eastchester  4c0dac537189c928c871d7b6
# 3   Bronx  Morris Heights  4babfacaf964a5203bdb3ae3
# 4   Bronx      Mott Haven  4f9de99ae4b08ea03a934ce3
#
#                                       Name
# 0               excellent taste restaurant
# 1  Yumi Asian Bistro & Hibachi Steak House
# 2          Jimmy's Best Chinese Restaurant
# 3                                Chop Chop
# 4                                   Ceetay

# %% [markdown]
# <h4>Bar Graph for number of Asian Resturants in each Borough</h4>
#
# A graph is plotted between the bOroughs and count of Asian Restaurants in each Borough to find where maximum of it is available

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Asian Resturants for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Asian Resturants', fontsize=15)
#giving a bar plot
asian_rest_ny.groupby('Borough')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# <h4>Graph Analysis</h4>
#
# <h5>From the above graph,it is clear that Queens has a maximum number of Asian Restaurants.<h5>

# %% [markdown]
# <h4>Exploring Queens</h4>
#
# 1) From the obtained dataframe of Asian Restaurants using Foresquare API,we slice the dataframe to find the data for Queens.

# %%
queens_data = asian_rest_ny[asian_rest_ny['Borough'] == 'Queens'].reset_index(drop=True)
queens_data.head()
# Out:
#   Borough     Neighborhood                        ID                      Name
# 0  Queens          Astoria  5834f3a437da1d46fb028a5e                    Rice K
# 1  Queens  Jackson Heights  4d6d7ebcfbf0a0934fc7008d     Lali Guras Restaurant
# 2  Queens         Elmhurst  4d6d7ebcfbf0a0934fc7008d     Lali Guras Restaurant
# 3  Queens         Elmhurst  56b25deb498ebc3a62af6179  Little House Cafe 聚香园茶餐厅
# 4  Queens     Forest Hills  4eb6fa550aaf1abedff6cba5         MoCA Asian Bistro

# %% [markdown]
# 2) From the dataset newyork.csv stored in the dataframe,all Queens data is seperated into a new dataframe

# %%
queen = df1[df1['Borough'] == 'Queens'].reset_index(drop=True)
queen.head()
# Out:
#   Borough     Neighborhood   Latitude  Longitude
# 0  Queens          Astoria  40.768509 -73.915654
# 1  Queens         Woodside  40.746349 -73.901842
# 2  Queens  Jackson Heights  40.751981 -73.882821
# 3  Queens         Elmhurst  40.744049 -73.881656
# 4  Queens     Howard Beach  40.654225 -73.838138

# %% [markdown]
# <h3>Plotting a graph to find out the neighborhoods of Queens and their count of Asian Restaurants</h3>
#
# A graph is plotted between the neighborhoods of Queens and their count of Asian Restaurants to find the neighborhoods with maximum of it.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Asian Resturants for each Neighborhood in New York City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 15)
#On y-axis
plt.ylabel('No.of Asian Resturants', fontsize=15)
#giving a bar plot
queens_data .groupby('Neighborhood')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# <h4>Graph Analysis:</h4>
#
# <h5>From the above graph,it is found that the neighborhoods-Bayside,Flushing and Forest Hills have equal number of Asian Restaurants which is highest among the other neighborhoods</h5>

# %% [markdown]
# <h4>Exploring Neighborhoods</h4>

# %%
#function generating the url for each neighborhood
def urlfunc(neighborhood_latitude,neighborhood_longitude):
    LIMIT = 100 
    radius = 1000


    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
    return url

# %%
#getting request and examining the results
def urlreq(url):
    results = requests.get(url).json()
    return results

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# <h4>Exploring Bayside</h4>

# %%
queen.loc[22, 'Neighborhood']
# Out:
# 'Bayside'

# %%
#finding neighbourhood's latitudal and longitudnal values
neighborhood_latitude = queen.loc[22, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = queen.loc[22, 'Longitude'] # neighborhood longitude value

neighborhood_name = queen.loc[22, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
a=urlfunc(neighborhood_latitude,neighborhood_longitude)#calling function to generate the url
print(a)
b=urlreq(a)
# Out:
# Latitude and longitude values of Bayside are 40.76604063281064, -73.77427363068671.
# https://api.foursquare.com/v2/venues/explore?&client_id=3G1FFILZXJ40SISIZQ32YIBEG5S0WTBLOFCOGKO3L2LFITXJ&client_secret=EG1T4EMV1U3PNHEIGRPSBQZBSZPPTF2ETI45MX04O0FWU2MY&v=20180605&ll=40.76604063281064,-73.77427363068671&radius=1000&limit=100

# %%
#cleaning the json structure into pandas dataframe
results=urlreq(a)
venues = results['response']['groups'][0]['items']
    
nearby_venues1 = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues1 =nearby_venues1.loc[:, filtered_columns]

# filter the category for each row
nearby_venues1['venue.categories'] = nearby_venues1.apply(get_category_type, axis=1)

# clean columns
nearby_venues1.columns = [col.split(".")[-1] for col in nearby_venues1.columns]

nearby_venues1.head()
# Out:
#                           name         categories        lat        lng
# 0          The French Workshop             Bakery  40.765404 -73.771861
# 1     Avli Little Greek Tavern   Greek Restaurant  40.765729 -73.771972
# 2                   Nippon Cha       Noodle House  40.764408 -73.771461
# 3  Ayna Agra Indian Restaurant  Indian Restaurant  40.765478 -73.771737
# 4            Fino Wine & Tapas           Wine Bar  40.764952 -73.771557

# %% [markdown]
# <h4>Slicing the dataframe for required categories</h4>
#
# The venue dataframe for the neighborhood "Bayside" is sliced into a new dataframe containing only the desired categories for the analysis as below

# %%
new =nearby_venues1[(nearby_venues1['categories'].isin(['Bank','Gym','Bubble Tea Shop','Bakery','Salon / Barbershop','Pharmacy','Park','Health & Beauty Service','Gym / Fitness Center','Supermarket','Supplement Shop','Grocery Store','Department Store','Tea Room','Spa']))]
new.head()
# Out:
#                        name categories        lat        lng
# 0       The French Workshop     Bakery  40.765404 -73.771861
# 7   Martha's Country Bakery     Bakery  40.763422 -73.770971
# 11             Massage Envy        Spa  40.766402 -73.772202
# 26           Crocheron Park       Park  40.772293 -73.769168
# 28     Better Body Bootcamp        Gym  40.769062 -73.773797

# %% [markdown]
# <h4>Visualization of the avaibility counts</h4>
#
# A graph is plotted between the selected categories and their counts for the neighborhood for further comparison with the avaibility of the desired in other neighborhoods

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of places available for each category in New York City')
#On x-axis
plt.xlabel('Categories', fontsize = 15)
#On y-axis
plt.ylabel('No.of availale categories', fontsize=15)
#giving a bar plot
new.groupby('categories')['categories'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
print(new['categories'].value_counts())
# Out:
# Pharmacy                   4
# Bakery                     3
# Supplement Shop            2
# Bank                       2
# Gym / Fitness Center       1
# Spa                        1
# Salon / Barbershop         1
# Tea Room                   1
# Health & Beauty Service    1
# Bubble Tea Shop            1
# Park                       1
# Gym                        1
# Name: categories, dtype: int64

# %% [markdown]
# <h5>Note:
# <P>For the requirement of Market/Store/Shop,Bayside has a Supplement Store.
# <P>For the requirement of Tea Shop,Bayside has Bubble Tea Shop.</h5>

# %% [markdown]
# <h4>Exploring Flushing</h4>

# %%
queen.loc[9, 'Neighborhood']
# Out:
# 'Flushing'

# %%
#finding neighbourhood's latitudal and longitudnal values
neighborhood_latitude = queen.loc[9, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = queen.loc[9, 'Longitude'] # neighborhood longitude value

neighborhood_name = queen.loc[9, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
a=urlfunc(neighborhood_latitude,neighborhood_longitude)#calling function to generate the url
print(a)
b=urlreq(a)#calling function to get the results for examining them
# Out:
# Latitude and longitude values of Flushing are 40.76445419697846, -73.83177300329581.
# https://api.foursquare.com/v2/venues/explore?&client_id=3G1FFILZXJ40SISIZQ32YIBEG5S0WTBLOFCOGKO3L2LFITXJ&client_secret=EG1T4EMV1U3PNHEIGRPSBQZBSZPPTF2ETI45MX04O0FWU2MY&v=20180605&ll=40.76445419697846,-73.83177300329581&radius=1000&limit=100

# %%
#cleaning the json structure into pandas dataframe
results=urlreq(a)
venues = results['response']['groups'][0]['items']
    
nearby_venues2 = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues2 =nearby_venues2.loc[:, filtered_columns]

# filter the category for each row
nearby_venues2['venue.categories'] = nearby_venues2.apply(get_category_type, axis=1)

# clean columns
nearby_venues2.columns = [col.split(".")[-1] for col in nearby_venues2.columns]

nearby_venues2.head()
# Out:
#                                  name             categories        lat  \
# 0                            Debasaki      Korean Restaurant  40.764852
# 1  Little Sheep Mongolian Hot Pot 小肥羊      Hotpot Restaurant  40.762083
# 2           New York Badminton Center   Gym / Fitness Center  40.765300
# 3                  Flushing Town Hall  Performing Arts Venue  40.763623
# 4       Joo Mak Gol Korean Restaurant                   Food  40.763658
#
#          lng
# 0 -73.831767
# 1 -73.828963
# 2 -73.834438
# 3 -73.830139
# 4 -73.831737

# %% [markdown]
# <h4>Slicing the dataframe for required categories</h4>
#
# The venue dataframe for the neighborhood "Flushing" is sliced into a new dataframe containing only the desired categories for the analysis as below

# %%
new1 =nearby_venues2[(nearby_venues2['categories'].isin(['Bank','Gym','Bubble Tea Shop','Bakery','Salon / Barbershop','Pharmacy','Park','Health & Beauty Service','Gym / Fitness Center','Supermarket','Grocery Store','Department Store','Tea Room','Spa']))]
new1.head()
# Out:
#                          name            categories        lat        lng
# 2   New York Badminton Center  Gym / Fitness Center  40.765300 -73.834438
# 6        Bodhi Fitness Center                   Gym  40.763666 -73.833211
# 8            Fang Gourmet Tea              Tea Room  40.759342 -73.830955
# 14                   Möge Tee       Bubble Tea Shop  40.760781 -73.830610
# 15           Prince Tea House              Tea Room  40.761275 -73.832847

# %% [markdown]
# <h4>Visualization of the avaibility counts</h4>
#
# A graph is plotted between the selected categories and their counts for the neighborhood for further comparison with the avaibility of the desired in other neighborhoods

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of places available for each category in New York City')
#On x-axis
plt.xlabel('Categories', fontsize = 15)
#On y-axis
plt.ylabel('No.of availale categories', fontsize=15)
#giving a bar plot
new1.groupby('categories')['categories'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# <h4>Graph Analysis:</h4>
#
# From the graph,the number of desired categories available is seen whose summary is printed below

# %%
print(new1['categories'].value_counts())
# Out:
# Bubble Tea Shop         11
# Bakery                   5
# Supermarket              2
# Tea Room                 2
# Grocery Store            1
# Gym / Fitness Center     1
# Department Store         1
# Gym                      1
# Name: categories, dtype: int64

# %% [markdown]
# <h5>Note:
# <P>For the requirement of Market/Store/Shop, Flushing has a Grocery Store,a Department Store and a Supermarket.
# <P>For the requirement of Tea Shop,Flushing has Bubble Tea Shop.</h5>

# %% [markdown]
# <h4>Exploring Forest Hills</h4>

# %%
queen.loc[6, 'Neighborhood']
# Out:
# 'Forest Hills'

# %%
#finding neighbourhood's latitudal and longitudnal values
neighborhood_latitude = queen.loc[6, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = queen.loc[6, 'Longitude'] # neighborhood longitude value

neighborhood_name = queen.loc[6, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
a=urlfunc(neighborhood_latitude,neighborhood_longitude)#calling function to generate the url
print(a)
b=urlreq(a)#calling function to get the results for examining them
# Out:
# Latitude and longitude values of Forest Hills are 40.72526378216503, -73.84447500788983.
# https://api.foursquare.com/v2/venues/explore?&client_id=3G1FFILZXJ40SISIZQ32YIBEG5S0WTBLOFCOGKO3L2LFITXJ&client_secret=EG1T4EMV1U3PNHEIGRPSBQZBSZPPTF2ETI45MX04O0FWU2MY&v=20180605&ll=40.72526378216503,-73.84447500788983&radius=1000&limit=100

# %%
#cleaning the json structure into pandas dataframe
results=urlreq(a)
venues = results['response']['groups'][0]['items']
    
nearby_venues3 = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues3 =nearby_venues3.loc[:, filtered_columns]

# filter the category for each row
nearby_venues3['venue.categories'] = nearby_venues3.apply(get_category_type, axis=1)

# clean columns
nearby_venues3.columns = [col.split(".")[-1] for col in nearby_venues3.columns]

nearby_venues3.head()
# Out:
#                       name  categories        lat        lng
# 0      Forest Hills Bagels  Bagel Shop  40.723600 -73.847820
# 1         Yellowstone Park        Park  40.726251 -73.847759
# 2          iLoveKickboxing  Boxing Gym  40.721522 -73.847939
# 3                   Banter         Bar  40.720820 -73.843169
# 4  Martha's Country Bakery      Bakery  40.720558 -73.845883

# %% [markdown]
# <h4>Slicing the dataframe for required categories</h4>
#
# The venue dataframe for the neighborhood "Forest Hils" is sliced into a new dataframe containing only the desired categories for the analysis as below

# %%
new2 =nearby_venues3[(nearby_venues3['categories'].isin(['Bank','Gym','Bubble Tea Shop','Bakery','Salon / Barbershop','Pharmacy','Park','Health & Beauty Service','Gym / Fitness Center','Supermarket','Department Store','Grocery Store','Tea Room','Spa']))]
new2.head()
# Out:
#                        name               categories        lat        lng
# 1          Yellowstone Park                     Park  40.726251 -73.847759
# 4   Martha's Country Bakery                   Bakery  40.720558 -73.845883
# 9       European Wax Center  Health & Beauty Service  40.720939 -73.846729
# 18           MacDonald Park                     Park  40.722239 -73.847141
# 23           La Boulangerie                   Bakery  40.719112 -73.841493

# %% [markdown]
# <h4>Visualization of the avaibility counts</h4>
#
# A graph is plotted between the selected categories and their counts for the neighborhood for further comparison with the avaibility of the desired in other neighborhoods

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of places available for each category in New York City')
#On x-axis
plt.xlabel('Categories', fontsize = 15)
#On y-axis
plt.ylabel('No.of availale categories', fontsize=15)
#giving a bar plot
new2.groupby('categories')['categories'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# <h4>Graph Analysis:</h4>
#
# From the graph,the number of desired categories available is seen whose summary is printed below

# %%
print(new2['categories'].value_counts())
# Out:
# Bakery                     6
# Park                       3
# Grocery Store              2
# Gym / Fitness Center       2
# Supermarket                1
# Health & Beauty Service    1
# Salon / Barbershop         1
# Pharmacy                   1
# Bank                       1
# Name: categories, dtype: int64

# %% [markdown]
# <h5>Note:
# For the requirement of Market/Store/Shop, Forest Hills has a Grocery Store and a Supermarket</h5>

# %% [markdown]
# <h3>Best Suited Neighborhood Recommendation</h3>
#
# Comparing the avaibility of the requirements in the three neighborhoods,the best suited neighborhood is Forest Hills.It is chosen because despite the less count of a few categories available,it fulfills almost all the requirement list as per the problem for a radius of 1000 meters.
#         The second recommendation is Bayside.
#
# <h5><ol>
#     <li>Forest Hills</li>
#     <li>Bayside</li>
#     </ol></h5>

# %% [markdown]
# <h3>Analysis of Forest Hills</h3>

# %%
print("List of all venues in Forest Hills:")

print(nearby_venues3[['name','categories']])
# Out:
# List of all venues in Forest Hills:
#                                        name                 categories
# 0                       Forest Hills Bagels                 Bagel Shop
# 1                          Yellowstone Park                       Park
# 2                           iLoveKickboxing                 Boxing Gym
# 3                                    Banter                        Bar
# 4                   Martha's Country Bakery                     Bakery
# 5                           Bangkok Cuisine            Thai Restaurant
# 6                Forest Hills Station House               Cocktail Bar
# 7                              Zen and Yoga                Yoga Studio
# 8                        Tu Casa Restaurant        Peruvian Restaurant
# 9                       European Wax Center    Health & Beauty Service
# 10                                 Kissfish         Seafood Restaurant
# 11                   Ripe Juice Bar & Grill                  Juice Bar
# 12                               Bareburger               Burger Joint
# 13                   Empire Wines & Liquors               Liquor Store
# 14                              Shake Shack               Burger Joint
# 15           TITLE Boxing Club Forest Hills                 Boxing Gym
# 16                  Cabana Restaurant & Bar       Caribbean Restaurant
# 17                   El Changarro Taco Cart                 Food Truck
# 18                           MacDonald Park                       Park
# 19                           Dirty Pierre's        American Restaurant
# 20                    West Side Tennis Club               Tennis Court
# 21                            Agora Taverna           Greek Restaurant
# 22                        Bath & Body Works             Cosmetics Shop
# 23                           La Boulangerie                     Bakery
# 24                       Waffles and Dinges                 Food Truck
# 25                     Forest Hills Stadium             Tennis Stadium
# 26                   Chipotle Mexican Grill              Burrito Place
# 27                     Spencer Pilates Arts             Pilates Studio
# 28                               Sushi Time           Sushi Restaurant
# 29            Great Wall Chinese Restaurant         Chinese Restaurant
# 30                             5 Burro Cafe                        Bar
# 31                            T-swirl crêpe                   Creperie
# 32               Narita Japanese Restaurant        Japanese Restaurant
# 33                             Nick's Pizza                Pizza Place
# 34                                Sakura-Ya          Food & Drink Shop
# 35                 Central Queens YM & YMHA       Gym / Fitness Center
# 36                     Memories Of Shanghai        Shanghai Restaurant
# 37                          Jack & Nellie's           Tapas Restaurant
# 38                            Spy C Cuisine        Szechuan Restaurant
# 39                               Roast N Co                 Restaurant
# 40                           Natural Market              Grocery Store
# 41                      Cheese of the World                Cheese Shop
# 42                   Queens Bagel Town Inc.                 Bagel Shop
# 43  Pahal Zan Falafel & Mediterranean Grill   Mediterranean Restaurant
# 44                        MoCA Asian Bistro           Asian Restaurant
# 45                        Victoria's Secret             Lingerie Store
# 46                            Red Pipe Cafe                       Café
# 47       LIRR Bridge - Forest Hills Trestle             Scenic Lookout
# 48                      Matiz Latin Cuisine  Latin American Restaurant
# 49                                     Rove    New American Restaurant
# 50                                     Arzu  Middle Eastern Restaurant
# 51                           Tamashii Ramen           Ramen Restaurant
# 52    Flagpole Green - Forest Hills Gardens                      Plaza
# 53                                Starbucks                Coffee Shop
# 54                              Tower Diner                      Diner
# 55                             Tuscan Hills         Italian Restaurant
# 56                 Pretty Woman Salon & Spa         Salon / Barbershop
# 57                      Bonelle Pastry Shop                     Bakery
# 58                           Paris Baguette                     Bakery
# 59                     Portofino Ristorante         Italian Restaurant
# 60                       Rosalia's Pizzeria                Pizza Place
# 61                        Mito Asian Fusion           Asian Restaurant
# 62                        Pasticceria Amore                     Bakery
# 63                                     Reef         Seafood Restaurant
# 64                     Carmel Grocery Store              Grocery Store
# 65                               Sushi Akio           Sushi Restaurant
# 66                             Guantanamera           Cuban Restaurant
# 67                                Taco King                 Taco Place
# 68              Knish Nosh Knishes & Franks                Snack Place
# 69                             CVS pharmacy                   Pharmacy
# 70                      Tu Arepa Pizza Cafe         Spanish Restaurant
# 71                      Underbridge Dog Run                    Dog Run
# 72                               Cuzco Peru        Peruvian Restaurant
# 73                            Grand Sichuan         Chinese Restaurant
# 74      Xin Taste Lan Zhou Hand Pull Noodle               Noodle House
# 75                       Bagels etc etc etc                 Bagel Shop
# 76                               Asian Bowl           Asian Restaurant
# 77                                 T-Mobile          Mobile Phone Shop
# 78                                   SUBWAY             Sandwich Place
# 79                             Midori Matsu        Japanese Restaurant
# 80                          Michaels Bagels                     Bakery
# 81                            The Mini Mart              Deli / Bodega
# 82                           Baskin-Robbins             Ice Cream Shop
# 83                           Sammie's To Go             Sandwich Place
# 84                                  Dunkin'                 Donut Shop
# 85                                   Pinang           Malay Restaurant
# 86                               Chase Bank                       Bank
# 87               Happy Fresh Tortilla Grill         Mexican Restaurant
# 88                                   Subway             Sandwich Place
# 89                                  Dunkin'                 Donut Shop
# 90                           Baskin-Robbins             Ice Cream Shop
# 91                                   Subway             Sandwich Place
# 92                        Red House Kitchen         Chinese Restaurant
# 93                    New York Sports Clubs       Gym / Fitness Center
# 94                                 Key Food                Supermarket
# 95         Grand Central Parkway at Exit 12               Intersection
# 96                       Motumbaxe Capoeira               Dance Studio
# 97               Flushing Meadow - Field 13                       Park
# 98            Row New York Queens Boathouse              Boat or Ferry
# 99                           Shogun Hibachi                 Restaurant

# %% [markdown]
# <h4>Getting the coordinates of Forest Hills</h4>

# %%
latitude = queen.loc[6, 'Latitude'] # neighborhood latitude value
longitude = queen.loc[6, 'Longitude'] # neighborhood longitude value

neighborhood_name = queen.loc[6, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               latitude, 
                                                               longitude))
# Out:
# Latitude and longitude values of Forest Hills are 40.72526378216503, -73.84447500788983.

# %% [markdown]
# <h4>Clustering All the venues of Forest Hills</h4>

# %%
map_ny1 = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, cat, name in zip(nearby_venues3['lat'], nearby_venues3['lng'], nearby_venues3['categories'], nearby_venues3['name']):
    label = '{}, {}'.format(cat, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ny1)  
    
map_ny1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h4>Clustering only the desired requirements of Forest Hills</h4>

# %%
map_ny2 = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, cat, name in zip(new2['lat'], new2['lng'], new2['categories'],new2['name']):
    label = '{}, {}'.format(cat, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ny2)  
    
map_ny2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
